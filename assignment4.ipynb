# %% [markdown]
# ## 1. What exactly is []?

# %%
""" the symboll [] shows  The empty list value, which is a list value that contains no items.

# %% [markdown]
# ## 2. In a list of values stored in a variable called spam, how would you assign the value &#39;hello&#39; as the
# third value? (Assume [2, 4, 6, 8, 10] are in spam.)

# %%
 spam = [2,4,6,8,10]
 spam[2] = 'hello' 
 print(spam)
# Out:
# [2, 4, 'hello', 8, 10]

# %% [markdown]
# ## 3. What is the value of spam[int(int(&#39;3&#39; * 2) / 11)]?

# %%
spam = [int(int('3' * 2) / 11)]
print(spam)
# Out:
# [3]

# %%
# 3' * 2 is the string '33', which is passed to int() before being divided by 11.
# This eventually evaluates to 3. Expressions can be used wherever values are used

# %% [markdown]
# ## 4. What is the value of spam[-1]?

# %%
spam= [1,2,6]
spam[-1]

# start from the ending of the list , tuple , etc
# Out:
# 6

# %% [markdown]
# ## 5. What is the value of spam[:2]?

# %%
spam= [3.14,'cat', 11,' cat', True]
spam[:2]
# [start = 0 : end = 2] so it will start from the 0th index And stop at the 2nd 
# index which is the [cat]
# Out:
# [3.14, 'cat']

# %% [markdown]
# ## 6. What is the value of bacon.index(&#39;cat&#39;)?

# %%
bacon= [3.14,'cat', 11,' cat', True]
bacon.index('cat')
# shoes the index of the cat
# Out:
# 1

# %% [markdown]
# ## 7. How does bacon.append(99) change the look of the list value in bacon?

# %%
bacon= [3.14,'cat', 11,' cat', True]
bacon.append(99)
print(bacon)
# add the 99 at the last of the list
# Out:
# [3.14, 'cat', 11, ' cat', True, 99]

# %% [markdown]
# ## 8. How does bacon.remove(&#39;cat&#39;) change the look of the list in bacon?

# %%
bacon= [3.14,'cat', 11,' cat', True]
bacon.remove('cat')
print(bacon)
# remove the frist the frist cat on the list
# Out:
# [3.14, 11, ' cat', True]

# %% [markdown]
# ## 9. What are the list concatenation and list replication operators?

# %%
# for the concatenation = + is used
o = "om" + "darkunde"
print(o)
# for the replication = * is used
print("om" * 2)
# Out:
# omdarkunde
# omom

# %% [markdown]
# ## 10. What is difference between the list methods append() and insert()?

# %%
# append() -- append always add the element in the last we can not add indexing in the append method 
# insert() --  insert add the element in the place which we want to add we can use indixing in the the insert

# %% [markdown]
# ## 11. What are the two methods for removing items from a list?

# %%
# pop() or remove() is used for removing

# %% [markdown]
# ## 12. Describe how list values and string values are identical.

# %%
# Strings and List is that in Python both are sequences.
# Strings and Lists is that both strings and lists have lengths
# Strings and Lists is that both strings and lists have a position

# %% [markdown]
# ## 13. What's the difference between tuples and lists

# %%
# tuple = tuple is immutable  we can not change the element 
# list = list is mutable  we can change the element

# %% [markdown]
# ## 14. How do you type a tuple value that only contains the integer 42?

# %%
i = (42,)
# The trailing comma is mandatory

# %% [markdown]
# ## 15. How do you get a list value&#39;s tuple form? How do you get a tuple value&#39;s list form?

# %%
om = [(1, 'sravan'), (2, 'ojaswi'), (3, 'bobby'),
        (4, 'rohith'), (5, 'gnanesh')]
mo =

# %% [markdown]
# ## 16. Variables that &quot;contain&quot; list values are not necessarily lists themselves. Instead, what do they
# contain?

# %%
# Variables will contain references to list values rather than list values themselves.

# %% [markdown]
# ## 17. How do you distinguish between copy.copy() and copy.deepcopy()?

# %%
# copy() create reference to original object. If you change copied object - you change the original object.
# . deepcopy() creates new object and does real copying of original object to new one
