# %% [markdown]
# ### 1.What are the two values of the Boolean data type? How do you write them?
# """
# A variable of the primitive data type boolean can have two values: True and False
# """

# %%
1 < 2
# Out:
# True

# %%
1  == 0
# Out:
# False

# %% [markdown]
# #2. What are the three different types of Boolean operators?
# """ there are three type of boolen operator that are AND OR NOT"""

# %% [markdown]
# ##  3. Make a list of each Boolean operator's truth tables (i.e. every possible combination of Boolean values for the operator and what it evaluate ).

# %%
and         or        not 
A B C     A B C       A B 
t t t     t t t       t f
t f f     t f t       f t
f t t     f t t
f f f     f f f

# %% [markdown]
# ##  4 What are the values of the following expressions?

# %%
(5 > 4) and (3 == 5) # (true) and (false) -- >false
not (5 > 4) # not(true) --> false
(5 > 4) or (3 == 5) # (true) and (false) -->true 
not ((5 > 4) or (3 == 5)) #not[true or false ]--> not (true) -->false
# Out:
# False

# %% [markdown]
# ## 5  What are the six comparison operators
# A > B --> greate than
# A < B --> smaller than
# A >= B --> greater than equal to
# A <= --> smaller than equal to
# A == B --> equal to
# A != B --> not equal to

# %% [markdown]
# ##6. How do you tell the difference between the equal to and assignment operators?Describe a condition and when you would use one.
#
# "=" this is assignment operator it will assign a value to a variable
# "==" this is equal to operator it will cheak both the variable are same or not
#  we will use the assignment oprator to assign any value to a variable and we will use the equal  to operato for cheaking the both the variables are smae of data type and value

# %%
A = 20
print (A)
# Out:
# 20

# %%
A = 20
B = 20 
A == B
# Out:
# True

# %% [markdown]
# ##7. Identify the three blocks in this code:
# spam = 0
# if spam == 10:
# print('eggs')
# if spam > 5:
# print('bacon')
# else:
# print('ham')
# print('spam')
# print('spam')

# %%
if spam == 10:
print('eggs') #frist block

# %%
if spam > 5:
print('bacon') #second block

# %%
else:
print('ham')
print('spam')
print('spam') #third block

# %% [markdown]
# ##8. Write code that prints Hello if 1 is stored in spam, prints Howdy if 2 is stored in spam, and prints Greetings! if anything else is stored in spam

# %%
spam = input()
if spam == "1" :
  print("Hello")
elif spam == "2" :
  print("Howdy")
else :
  print("Greeting!")
# Out:
# 1
# Hello

# %% [markdown]
# ## 9.If your programme is stuck in an endless loop, what keys you’ll press?

# %%
# for getting out we will break the loop 
# by using ctrl + MZ  we can stop the endless loop
# by using ctrl + c we can also stop the loop

# %% [markdown]
# ## 10  How can you tell the difference between break and continue?

# %%
# break --  when the condition become false then the break statement stop the loop and give us the output
#continue -- while the condition become wrong after that the contine cheak other element and then and after cheaking all the elements it give us the output

# %% [markdown]
# ## 11. In a for loop, what is the difference between range(10), range(0, 10), and range(0, 10, 1)?

# %%
 # range(10) discribes the element present at the 10 index a
 # range (0, 10) discribes the starting index and the ending index for which the for loop will work (start ,end)
 # range (0,10,1)disbribes the starting index , ending index and the steps to jump in which the for loop will work (start,end,steps)

# %% [markdown]
# ## 12. Write a short program that prints the numbers 1 to 10 using a for loop. Then write an equivalent program that prints the numbers 1 to 10 using a while loop.

# %%
for i in range (1,11):
print(i)
and:
i = 1

# %%
while i <= 10:
print(i)
i = i + 1

# %% [markdown]
# ## 13. If you had a function named bacon() inside a module named spam, how would you call it after importing spam?

# %%
#This function can be called with spam.bacon().
