# %% [markdown]
# ## 1. What are escape characters, and how do you use them?

# %%
# To insert characters that are illegal in a string, use an escape character.
#An escape character is a backslash \ followed by the character you want to insert.

# %% [markdown]
# ## 2. What do the escape characters n and t stand for?

# %%
#escape character n stand for the new line 
#escape character t stand for the carriage return

# %% [markdown]
# ## 3. What is the way to include backslash characters in a string?

# %%
# "\\" is used to backslash chracters in the string

# %% [markdown]
# ## 4. The string &quot;Howl&#39;s Moving Castle&quot; is a correct value. Why isn&#39;t the single quote character in the
# word Howl&#39;s not escaped a problem?

# %%
# The single quote in Howl's is fine because we used double quotes to mark the beginning and end of the string.

# %% [markdown]
# ##5. How do you write a string of newlines if you don&#39;t want to use the n character?

# %%
# we can use the print statement for write on the new line print defaultly print the satatement on the next line 
print("hello")
print("world")
# Out:
# hello
# world

# %% [markdown]
# ## 6. What are the values of the given expressions?
# &#39;Hello, world!&#39;[1]
# &#39;Hello, world!&#39;[0:5]
# &#39;Hello, world!&#39;[:5]
# &#39;Hello, world!&#39;[3:]

# %%
'Hello, world!'[1] # grabes the letter on the index of the
# Out:
# 'e'

# %%
'Hello, world!'[0:5] #[start : stop] describes the start and the end of the slicising
# Out:
# 'Hello'

# %%
'Hello, world!'[:5] #[start : stop] describes the start and the end of the slicising
# Out:
# 'Hello'

# %%
'Hello, world!'[3:] #[start : stop] describes the start and the end of the slicising
# Out:
# 'lo, world!'

# %% [markdown]
# ## 7. What are the values of the following expressions?
# &#39;Hello&#39;.upper()
# &#39;Hello&#39;.upper().isupper()
# &#39;Hello&#39;.upper().lower()

# %%
'Hello'.upper() #change the alphabet prestsent in the string to upper case
# Out:
# 'HELLO'

# %%
'Hello'.upper().isupper() #upper() changes it to uppercase and the isupper() will workd ase the if else like is the hello is uppercase yes
#then it will say yes or no then it will say no
# Out:
# True

# %%
'Hello'.upper().lower() #upper() changes it to uppercase and the islower() will workd ase the if else like is the hello is lowercase yes
#then it will say yes or no then it will say no
# Out:
# 'hello'

# %% [markdown]
# ## 8. What are the values of the following expressions?
# &#39;Remember, remember, the fifth of July.&#39;.split()
# &#39;-&#39;.join(&#39;There can only one.&#39;.split())

# %%
'Remember, remember, the fifth of July'.split() # The split() method splits a string into a list.
# Out:
# ['Remember,', 'remember,', 'the', 'fifth', 'of', 'July']

# %%
'-'.join('There can only one'.split()) ## The split() method splits a string into a list. and the .join method will join all the splited string through '-'
# Out:
# 'There-can-only-one'

# %% [markdown]
# ## 9. What are the methods for right-justifying, left-justifying, and centering a string?

# %%
#str.ljust(s, width[, fillchar])
#str.rjust(s, width[, fillchar])
#str.center(s, width[, fillchar])

om = "hello"
print(om.ljust)
# Out:
# <built-in method ljust of str object at 0x7f296d5af130>

# %% [markdown]
# ## 10. What is the best way to remove whitespace characters from the start or end?

# %%
# Use the ".strip()" method to remove whitespace and characters from the beginning and the end of a string.
# Use the ".lstrip()" method to remove whitespace and characters only from the beginning of a string.
# Use the ".rstrip()" method to remove whitespace and characters only from the end of a string.
