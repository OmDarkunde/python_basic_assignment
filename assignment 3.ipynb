# %% [markdown]
# ##1. Why are functions advantageous to have in your programs?

# %%
"""allows us to reduce a complicated program into smaller, more manageable chunks, which reduces the overall complexity of our program"""

# %% [markdown]
# ##2. When does the code in a function run: when it&#39;s specified or when it&#39;s called?

# %%
""" when we call the function then it will work """

# %% [markdown]
# ##3. What statement creates a function?

# %%
"""The “def” keyword is a statement for defining a function in Python. """

# %% [markdown]
# ## 4. What is the difference between a function and a function call?

# %%
""" function is a block of code in which we can perform certain activity continuesly
when we creat a function it will not work automatically it will only work when we call the functin to some 
action on the given data """

# %% [markdown]
# ## 5. How many global scopes are there in a Python program? How many local scopes?

# %%
"""there is i=one global scope in python programing 
and there are four local scope  """

# %% [markdown]
# ## 6. What happens to variables in a local scope when the function call returns?

# %%
""" When the execution of the function terminates (returns), the local variables are destroyed. """

# %% [markdown]
# ## 7. What is the concept of a return value? Is it possible to have a return value in an expression?

# %%
""" A return statement is used to end the execution of the function call and “returns” 
the result (value of the expression following the return keyword) to the caller 

"""

# %% [markdown]
# ## 8. If a function does not have a return statement, what is the return value of a call to that function?

# %%
""" If no return statement appears in a function definition, control automatically
 returns to the calling function after the last statement of the called function is executed. 
 In this case, the return value of the called function is undefined. """

# %% [markdown]
# ## 9. How do you make a function variable refer to the global variable?

# %%
""" To create a global variable inside a function, you can use the global keyword. """

# %% [markdown]
# ## 10. What is the data type of None?

# %%
"""None is a data type of its own (NoneType) and only None can be None. """
# Out:
# 'None is a data type of its own (NoneType) and only None can be None. '

# %% [markdown]
# ## 11. What does the sentence import areallyourpetsnamederic do?

# %%
"""That import statement imports a module named areallyourpetsnamederic."""

# %% [markdown]
# ## 12. If you had a bacon() feature in a spam module, what would you call it after importing spam?

# %%
""" This function can be called with spam.bacon(). """

# %% [markdown]
# ## 13. What can you do to save a programme from crashing if it encounters an error?

# %%
""" Place the line of code that might cause an error in a try clause """

# %% [markdown]
# ## 14. What is the purpose of the try clause? What is the purpose of the except clause?

# %%
""" The code that could potentially cause an error goes in the try clause.
-The code that executes if an error happens goes in the except clause."""
